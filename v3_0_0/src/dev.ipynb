# %% [markdown]
# # インポート

# %%
import pandas as pd
from pathlib import Path

COMMON_DATA_DIR = Path("..", "..", "common", "data")
RAWDF_DIR = COMMON_DATA_DIR / "rawdf"
# Out:
# /var/folders/g3/gfhkc67x6m71nt0rd03wcvxc0000gn/T/ipykernel_55870/1450976773.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # 予測時の処理

# %% [markdown]
# ## レース前日準備

# %%
import preprocessing

horse_results_preprocessed = preprocessing.process_horse_results(
    save_filename="horse_results_prediction.csv"
)

# %%
horse_results_preprocessed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3084 entries, 0 to 3101
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   horse_id      3084 non-null   int64
#  1   date          3084 non-null   datetime64[ns]
#  2   rank          3084 non-null   float64
#  3   prize         3084 non-null   float64
#  4   rank_diff     3082 non-null   float64
#  5   weather       3082 non-null   float64
#  6   race_type     3084 non-null   int64
#  7   course_len    3084 non-null   int64
#  8   ground_state  3084 non-null   int64
#  9   race_class    2869 non-null   float64
#  10  n_horses      3084 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(5)
# memory usage: 289.1 KB

# %%
horse_results_preprocessed[horse_results_preprocessed["rank_diff"].isnull()]
# Out:
#         horse_id       date  rank  prize  rank_diff  weather  race_type  \
# 2816  2018105192 2023-04-15   7.0    0.0        NaN      NaN          1
# 2968  2020110136 2023-02-25  12.0    0.0        NaN      NaN          0
#
#       course_len  ground_state  race_class  n_horses
# 2816        1400             1         8.0        11
# 2968        1600             0         6.0        13

# %%
from feature_engineering import PredictionFeatureCreator
# %load_ext autoreload

# %%
pfc = PredictionFeatureCreator()

# %%
pfc.agg_horse_n_races()

# %%
pfc.agg_horse_n_races_df
# Out:
#            date       race_id    horse_id  rank_3races  prize_3races  \
# 0    2024-06-01  202405030101  2019100108     6.666667     66.666667
# 1    2024-06-01  202405030101  2019104899     8.666667      0.000000
# 2    2024-06-01  202405030101  2016103092     8.666667      0.000000
# 3    2024-06-01  202405030101  2020102800     6.666667     80.000000
# 4    2024-06-01  202405030101  2019105143    13.000000      0.000000
# ..          ...           ...         ...          ...           ...
# 296  2024-06-01  202408040112  2019104288     2.000000    470.000000
# 297  2024-06-01  202408040112  2018104208     9.000000     76.666667
# 298  2024-06-01  202408040112  2020104845     8.666667      0.000000
# 299  2024-06-01  202408040112  2021100161     4.333333    443.333333
# 300  2024-06-01  202408040112  2020101230    10.666667     76.666667
#
#      rank_5races  prize_5races  rank_10races  prize_10races  rank_1000races  \
# 0            7.6          40.0      5.900000     208.000000        4.538462
# 1           10.2           0.0      9.300000     134.710000        6.764706
# 2            8.8           0.0      7.700000      12.000000        6.945946
# 3            8.0          48.0      6.900000     184.900000        6.461538
# 4           13.4           0.0     11.600000     158.640000        8.687500
# ..           ...           ...           ...            ...             ...
# 296          3.2         306.0      3.000000     277.000000        5.681818
# 297          7.4         104.0      7.800000      63.400000        5.648649
# 298          7.8           0.0      6.500000     140.500000        6.615385
# 299          4.4         310.0      5.666667     258.333333        5.666667
# 300          7.4         240.0      7.800000     120.000000        7.266667
#
#      prize_1000races
# 0         218.500000
# 1         396.276471
# 2           8.500000
# 3         186.230769
# 4         193.525000
# ..               ...
# 296       176.409091
# 297       145.200000
# 298       114.076923
# 299       258.333333
# 300       114.666667
#
# [301 rows x 11 columns]

# %% [markdown]
# ### htmlの取得

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

options = Options()
# ヘッドレスモード（バックグラウンド）で起動
options.add_argument("--headless")
# その他のクラッシュ対策
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")
driver_path = ChromeDriverManager().install()

url = "https://race.netkeiba.com/race/shutuba.html?race_id=202405030101"
with webdriver.Chrome(service=Service(driver_path), options=options) as driver:
    driver.implicitly_wait(10)
    driver.get(url)
    html = driver.page_source

# %%
html
# Out:
# '<html><head><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/spa-detector.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/feed-card-placeholder.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/explore-more.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/article-detection.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/distance-from-article.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/userx.20240530-42-RELEASE.es6.js"></script><script type="text/javascript" src="//gum.criteo.com/sync?c=72&amp;r=2&amp;j=TRC.getRTUS" charset="UTF-8" async="async"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-BQDXGQBP6X&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-B2L5N4JT6V&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.clarity.ms/tag/dfos4lrrd0"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script charset="UTF-8" type="text/javascript" src="https://cdn.taboola.com/libtrc/impl.20240530-42-RELEASE.js"></script><style type="text/css">.swal-icon--error{border-color:#f27474;-webkit-animation:animateErrorIcon .5s;animation:animateErrorIcon .5s}.swal-icon--error__x-mark{position:relative;display:block;-webkit-animation:animateXMark .5s;animation:animateXMark .5s}.swal-icon--error__line{position:absolute;height:5px;width:47px;background-color:#f27474;display:block;top:37px;border-radius:2px}.swal-icon--error__line--left{-webkit-transform:rotate(45deg);transform:rotate(45deg);left:17px}.swal-icon--error__line--right{-webkit-transform:rotate(-45deg);transform:rotate(-45deg);right:16px}@-webkit-keyframes animateErrorIcon{0%{-webkit-transform:rotateX(100deg);transform:rotateX(100deg);opacity:0}to{-webkit-transform:rotateX(0deg);transform:rotateX(0deg);opacity:1}}@keyframes animateErrorIcon{0%{-webkit-transform:rotateX(100deg);transform:rotateX(100deg);opacity:0}to{-webkit-transform:rotateX(0deg);transform:rotateX(0deg);opacity:1}}@-webkit-keyframes animateXMark{0%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}50%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}80%{-webkit-transform:scale(1.15);transform:scale(1.15);margin-top:-6px}to{-webkit-transform:scale(1);transform:scale(1);margin-top:0;opacity:1}}@keyframes animateXMark{0%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}50%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}80%{-webkit-transform:scale(1.15);transform:scale(1.15);margin-top:-6px}to{-webkit-transform:scale(1);transform:scale(1);margin-top:0;opacity:1}}.swal-icon--warning{border-color:#f8bb86;-webkit-animation:pulseWarning .75s infinite alternate;animation:pulseWarning .75s infinite alternate}.swal-icon--warning__body{width:5px;height:47px;top:10px;border-radius:2px;margin-left:-2px}.swal-icon--warning__body,.swal-icon--warning__dot{position:absolute;left:50%;background-color:#f8bb86}.swal-icon--warning__dot{width:7px;height:7px;border-radius:50%;margin-left:-4px;bottom:-11px}@-webkit-keyframes pulseWarning{0%{border-color:#f8d486}to{border-color:#f8bb86}}@keyframes pulseWarning{0%{border-color:#f8d486}to{border-color:#f8bb86}}.swal-icon--success{border-color:#a5dc86}.swal-icon--success:after,.swal-icon--success:before{content:"";border-radius:50%;position:absolute;width:60px;height:120px;background:#fff;-webkit-transform:rotate(45deg);transform:r ...

# %%
# %autoreload

# %%
pfc = PredictionFeatureCreator()
pfc.fetch_shutuba_table_html(race_id="202405030101")

# %%
html = pfc.html

# %% [markdown]
# ### レース結果テーブルの作成
# PredictionFeatureCreator.fetch_results()で、
# - rawデータの作成
# - 前処理
#
# をどちらもやるイメージ

# %%
import pandas as pd

df = pd.read_html(html)[0]
df
# Out:
# /var/folders/g3/gfhkc67x6m71nt0rd03wcvxc0000gn/T/ipykernel_48751/1051395732.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(html)[0]
#    枠 馬 番   印         馬名  性齢    斤量   騎手     厩舎  馬体重 (増減)    オッズ  人気 お気に入り馬
#    枠 馬 番   印         馬名  性齢    斤量   騎手     厩舎  馬体重 (増減)    オッズ  人気     登録  メモ
# 0  1   1  --  プリモスペランツァ  牡5  60.0   田村   栗東中竹   500(-6)    3.1   1    NaN NaN
# 1  2   2  --      インプレス  牡5  60.0  小牧加  栗東佐々木  526(-12)    5.1   3    NaN NaN
# 2  3   3  --     コルドゥーン  牡8  60.0    伴   美浦石栗  474(+12)  121.9   8    NaN NaN
# 3  4   4  --   オメガリッチマン  牡4  60.0   高田   栗東安田   446(-2)    3.5   2    NaN NaN
# 4  5   5  --  インディゴブラック  セ5  60.0   小坂  栗東奥村豊   512(+2)   10.0   6    NaN NaN
# 5  6   6  --   スペキュレーター  牡5  60.0  江田勇  美浦伊藤伸  506(+22)  146.9   9    NaN NaN
# 6  7   7  --    キタノブレイド  牡5  60.0  石神深   美浦萱野   476(+4)    6.4   4    NaN NaN
# 7  7   8  --     フジフォンテ  牡5  60.0  大江圭   美浦粕谷   464(-4)  163.3  10    NaN NaN
# 8  8   9  --   ダノンジャッカル  牡5  60.0  西谷誠  栗東中内田  462(+12)    7.5   5    NaN NaN
# 9  8  10  --      ヴラディア  牡5  60.0   上野   美浦小西   496(+2)   19.9   7    NaN NaN

# %%
df.columns = df.columns.get_level_values(1)
df
# Out:
#    枠  馬 番   印         馬名  性齢    斤量   騎手     厩舎  馬体重 (増減)    オッズ  人気  登録  メモ
# 0  1    1  --  プリモスペランツァ  牡5  60.0   田村   栗東中竹   500(-6)    3.1   1 NaN NaN
# 1  2    2  --      インプレス  牡5  60.0  小牧加  栗東佐々木  526(-12)    5.1   3 NaN NaN
# 2  3    3  --     コルドゥーン  牡8  60.0    伴   美浦石栗  474(+12)  121.9   8 NaN NaN
# 3  4    4  --   オメガリッチマン  牡4  60.0   高田   栗東安田   446(-2)    3.5   2 NaN NaN
# 4  5    5  --  インディゴブラック  セ5  60.0   小坂  栗東奥村豊   512(+2)   10.0   6 NaN NaN
# 5  6    6  --   スペキュレーター  牡5  60.0  江田勇  美浦伊藤伸  506(+22)  146.9   9 NaN NaN
# 6  7    7  --    キタノブレイド  牡5  60.0  石神深   美浦萱野   476(+4)    6.4   4 NaN NaN
# 7  7    8  --     フジフォンテ  牡5  60.0  大江圭   美浦粕谷   464(-4)  163.3  10 NaN NaN
# 8  8    9  --   ダノンジャッカル  牡5  60.0  西谷誠  栗東中内田  462(+12)    7.5   5 NaN NaN
# 9  8   10  --      ヴラディア  牡5  60.0   上野   美浦小西   496(+2)   19.9   7 NaN NaN

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "lxml").find("table", class_="Shutuba_Table")
soup
# Out:
# <table class="Shutuba_Table RaceTable01 ShutubaTable tablesorter tablesorter-default" role="grid">
# <thead>
# <tr class="Header tablesorter-headerRow" role="row">
# <th aria-disabled="true" aria-label="枠: No sort applied, sorting is disabled" aria-sort="none" class="Waku tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="0" role="columnheader" rowspan="2" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">枠</div></th>
# <th aria-disabled="false" aria-label="馬番: No sort applied, activate to apply an ascending sort" aria-sort="none" class="Umaban sort_common tablesorter-header tablesorter-headerUnSorted" data-column="1" role="columnheader" rowspan="2" scope="col" style="user-select: none;" tabindex="0" unselectable="on"><div class="tablesorter-header-inner"><div class="Inner_Shutuba">馬<br/>番<span class="sort_icon" style="display: block;"><i class="fas fa-sort"></i></span></div></div></th>
# <th aria-disabled="true" aria-label="印: No sort applied, sorting is disabled" aria-sort="none" class="CheckMark tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="2" role="columnheader" rowspan="2" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">印
# <div class="ChangeMarkBtn">
# <div class="BtnInput BtnInputTick">
# <input class="BtnInputLabel" onclick="change_mark_mode('shutuba','202405030101', _race_cookie_domain_);" type="button" value="切替"/>
# </div>
# </div><!-- /.ChangeMarkBtn -->
# </div></th>
# <th aria-disabled="false" aria-label="馬名: No sort applied, activate to apply an ascending sort" aria-sort="none" class="HorseInfo sort_common tablesorter-header tablesorter-headerUnSorted" data-column="3" id="sort_cell_name" role="columnheader" rowspan="2" scope="col" style="user-select: none;" tabindex="0" unselectable="on"><div class="tablesorter-header-inner">
# <div class="Inner_Shutuba">
# <span class="HorseName">馬名</span><span class="sort_icon" style="display: block;"><i class="fas fa-sort"></i></span>
# </div>
# </div></th>
# <th aria-disabled="true" aria-label="性齢: No sort applied, sorting is disabled" aria-sort="none" class="Barei tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="4" role="columnheader" rowspan="2" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">性齢</div></th>
# <th aria-disabled="false" aria-label="斤量: No sort applied, activate to apply an ascending sort" aria-sort="none" class="Dredging sort_common tablesorter-header tablesorter-headerUnSorted" data-column="5" role="columnheader" rowspan="2" scope="col" style="user-select: none;" tabindex="0" unselectable="on"><div class="tablesorter-header-inner"><div class="Inner_Shutuba">斤量<span class="sort_icon" style="display: block;"><i class="fas fa-sort"></i></span></div></div></th>
# <th aria-disabled="true" aria-label="騎手: No sort applied, sorting is disabled" aria-sort="none" class="Jockey tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="6" role="columnheader" rowspan="2" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">騎手</div></th>
# <th aria-disabled="true" aria-label="厩舎: No sort applied, sorting is disabled" aria-sort="none" class="Trainer tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="7" role="columnheader" rowspan="2" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">厩舎</div></th>
# <th aria-disabled="false" aria-label="馬体重(増減): No sort applied, activate to apply an ascending sort" aria-sort="none" class="Weight sort_common tablesorter-header tablesorter-headerUnSorted" data-column="8" id="sort_cell_weight" role="columnheader" rowspan="2" scope="col" style="user-select: none;" tabindex="0" unselectable="on"><div class="tablesorter-header-inner"><div class="Inner_Shutuba">馬体重<br/><small>(増減)</small><span class="sort_icon" style="display: block;"><i class="fas fa-sort"></i></span></div></div></th>
# <th aria-disabled="true" aria-label="オッズ
#
# 更新: No sort applied, sorting is disabled" aria-sort="none" class="Popular tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="9" id="sort_cell_odds" role="columnheader" rowspan="2" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">
# <div class="Tooltip_OddsUpLimit_Wrap" id="odds_update_info">
# <span id="odds_title">オッズ</span>
# <button class="BtnInputLabel OddsUpdataBtn LiveOddsUpdate" id="act-manual_update" style="display:none" type="button">
# <span class="OddsUpLimitTxt01">更新</span>
# </button>
# </div></div></th>
# <th aria-disabled="false" aria-label="人気: No sort applied, activate to apply an ascending sort" aria-sort="none" class="Popular Popular_Ninki Txt_C sort_common tablesorter-header tablesorter-headerUnSorted" data-column="10" id="sort_cell_ninki" role="columnheader" rowspan="2" scope="col" style="user-select: none;" tabindex="0" unselectable="on"><div class="tablesorter-header-inner"><div class="Inner_Shutuba">人気<span class="sort_icon" style="display: block;"><i class="fas fa-sort"></i></span></div></div></th>
# <th aria-disabled="true" aria-label="お気に入り馬: No sort applied, sorting is disabled" aria-sort="none" class="FavHorse tablesorter-header sorter-false tablesorter-headerUnSorted" colspan="2" data-column="11" role="columnheader" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner"><a href="https://db.netkeiba.com/bookmark/horse_bookmark_list.html">お気に入り馬</a></div></th>
# </tr>
# <tr class="Header FavHorseSub tablesorter-headerRow" role="row">
# <th aria-disabled="true" aria-label="登録: No sort applied, sorting is disabled" aria-sort="none" class="FavRegist tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="11" role="columnheader" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">登録</div></th>
# <th aria-disabled="true" aria-label="メモ: No sort applied, sorting is disabled" aria-sort="none" class="Memo tablesorter-header sorter-false tablesorter-headerUnSorted" data-column="12" role="columnheader" scope="col" style="user-select: none;" unselectable="on"><div class="tablesorter-header-inner">メモ</div></th>
# </tr>
# </thead>
# <tbody aria-live="polite" aria-relevant="all"><tr class="HorseList" id="tr_10" role="row">
# <td class="Waku1 Txt_C"><span>1</span></td>
# <td class="Umaban1 Txt_C">1</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_10" id="mark_10" name="10" style="display: none;">
# <option data-html-text="--" value="1_0">--</option><option data-html-text="◎" value="1_1">◎</option><option data-html-text="◯" value="1_2">◯</option><option data-html-text="▲" value="1_3">▲</option><option data-html-text="△" value="1_4">△</option><option data-html-text="☆" value="1_5">☆</option><option data-html-text="&amp;#10003" value="1_98">&amp;#10003</option><option data-html-text="消" value="1_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019100108" target="_blank" title="プリモスペランツァ">プリモスペランツァ<img alt="" class="disp_none Favorite" id="myhorse_2019100108" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01105/" target="_blank" title="田村">田村</a>
# </td>
# <td class="Trainer"><span class="Label2">栗東</span><a href="https://db.netkeiba.com/trainer/result/recent/01039/" target="_blank" title="中竹">中竹</a></td>
# <td class="Weight">
# 500<small>(-6)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color Odds_Ninki" id="odds-1_01" style="font-weight : bold">3.1</span></td>
# <td class="Popular Popular_Ninki Txt_C BgYellow">
# <span id="ninki-1_01">1</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019100108&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019100108" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019100108" height="20" id="myhorse1_2019100108" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019100108&amp;race_id=202405030101" id="Bamei_2019100108" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_2" role="row">
# <td class="Waku2 Txt_C"><span>2</span></td>
# <td class="Umaban2 Txt_C">2</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_2" id="mark_2" name="2" style="display: none;">
# <option data-html-text="--" value="2_0">--</option><option data-html-text="◎" value="2_1">◎</option><option data-html-text="◯" value="2_2">◯</option><option data-html-text="▲" value="2_3">▲</option><option data-html-text="△" value="2_4">△</option><option data-html-text="☆" value="2_5">☆</option><option data-html-text="&amp;#10003" value="2_98">&amp;#10003</option><option data-html-text="消" value="2_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019104899" target="_blank" title="インプレス">インプレス<img alt="" class="disp_none Favorite" id="myhorse_2019104899" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01196/" target="_blank" title="小牧加">小牧加</a>
# </td>
# <td class="Trainer"><span class="Label2">栗東</span><a href="https://db.netkeiba.com/trainer/result/recent/00429/" target="_blank" title="佐々木">佐々木</a></td>
# <td class="Weight">
# 526<small>(-12)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color Odds_Ninki" id="odds-1_02" style="font-weight : bold">5.1</span></td>
# <td class="Popular Popular_Ninki Txt_C BgOrange">
# <span id="ninki-1_02">3</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019104899&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019104899" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019104899" height="20" id="myhorse1_2019104899" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019104899&amp;race_id=202405030101" id="Bamei_2019104899" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_6" role="row">
# <td class="Waku3 Txt_C"><span>3</span></td>
# <td class="Umaban3 Txt_C">3</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_6" id="mark_6" name="6" style="display: none;">
# <option data-html-text="--" value="3_0">--</option><option data-html-text="◎" value="3_1">◎</option><option data-html-text="◯" value="3_2">◯</option><option data-html-text="▲" value="3_3">▲</option><option data-html-text="△" value="3_4">△</option><option data-html-text="☆" value="3_5">☆</option><option data-html-text="&amp;#10003" value="3_98">&amp;#10003</option><option data-html-text="消" value="3_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="Icon_HorseMark Icon_MaruChi"></span><span class="HorseName"><a href="https://db.netkeiba.com/horse/2016103092" target="_blank" title="コルドゥーン">コルドゥーン<img alt="" class="disp_none Favorite" id="myhorse_2016103092" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡8</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01149/" target="_blank" title="伴">伴</a>
# </td>
# <td class="Trainer"><span class="Label1">美浦</span><a href="https://db.netkeiba.com/trainer/result/recent/01043/" target="_blank" title="石栗">石栗</a></td>
# <td class="Weight">
# 474<small>(+12)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color" id="odds-1_03" style="font-weight : bold">121.9</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_03">8</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2016103092&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2016103092" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2016103092" height="20" id="myhorse1_2016103092" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2016103092&amp;race_id=202405030101" id="Bamei_2016103092" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_4" role="row">
# <td class="Waku4 Txt_C"><span>4</span></td>
# <td class="Umaban4 Txt_C">4</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_4" id="mark_4" name="4" style="display: none;">
# <option data-html-text="--" value="4_0">--</option><option data-html-text="◎" value="4_1">◎</option><option data-html-text="◯" value="4_2">◯</option><option data-html-text="▲" value="4_3">▲</option><option data-html-text="△" value="4_4">△</option><option data-html-text="☆" value="4_5">☆</option><option data-html-text="&amp;#10003" value="4_98">&amp;#10003</option><option data-html-text="消" value="4_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2020102800" target="_blank" title="オメガリッチマン">オメガリッチマン<img alt="" class="disp_none Favorite" id="myhorse_2020102800" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡4</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01046/" target="_blank" title="高田">高田</a>
# </td>
# <td class="Trainer"><span class="Label2">栗東</span><a href="https://db.netkeiba.com/trainer/result/recent/01164/" target="_blank" title="安田">安田</a></td>
# <td class="Weight">
# 446<small>(-2)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color Odds_Ninki" id="odds-1_04" style="font-weight : bold">3.5</span></td>
# <td class="Popular Popular_Ninki Txt_C BgBlue02">
# <span id="ninki-1_04">2</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2020102800&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2020102800" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2020102800" height="20" id="myhorse1_2020102800" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2020102800&amp;race_id=202405030101" id="Bamei_2020102800" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_1" role="row">
# <td class="Waku5 Txt_C"><span>5</span></td>
# <td class="Umaban5 Txt_C">5</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_1" id="mark_1" name="1" style="display: none;">
# <option data-html-text="--" value="5_0">--</option><option data-html-text="◎" value="5_1">◎</option><option data-html-text="◯" value="5_2">◯</option><option data-html-text="▲" value="5_3">▲</option><option data-html-text="△" value="5_4">△</option><option data-html-text="☆" value="5_5">☆</option><option data-html-text="&amp;#10003" value="5_98">&amp;#10003</option><option data-html-text="消" value="5_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019105143" target="_blank" title="インディゴブラック">インディゴブラック<img alt="" class="disp_none Favorite" id="myhorse_2019105143" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">セ5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01063/" target="_blank" title="小坂">小坂</a>
# </td>
# <td class="Trainer"><span class="Label2">栗東</span><a href="https://db.netkeiba.com/trainer/result/recent/01146/" target="_blank" title="奥村豊">奥村豊</a></td>
# <td class="Weight">
# 512<small>(+2)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color" id="odds-1_05" style="font-weight : bold">10.0</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_05">6</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019105143&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019105143" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019105143" height="20" id="myhorse1_2019105143" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019105143&amp;race_id=202405030101" id="Bamei_2019105143" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_7" role="row">
# <td class="Waku6 Txt_C"><span>6</span></td>
# <td class="Umaban6 Txt_C">6</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_7" id="mark_7" name="7" style="display: none;">
# <option data-html-text="--" value="6_0">--</option><option data-html-text="◎" value="6_1">◎</option><option data-html-text="◯" value="6_2">◯</option><option data-html-text="▲" value="6_3">▲</option><option data-html-text="△" value="6_4">△</option><option data-html-text="☆" value="6_5">☆</option><option data-html-text="&amp;#10003" value="6_98">&amp;#10003</option><option data-html-text="消" value="6_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019102792" target="_blank" title="スペキュレーター">スペキュレーター<img alt="" class="disp_none Favorite" id="myhorse_2019102792" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01023/" target="_blank" title="江田勇">江田勇</a>
# </td>
# <td class="Trainer"><span class="Label1">美浦</span><a href="https://db.netkeiba.com/trainer/result/recent/01031/" target="_blank" title="伊藤伸">伊藤伸</a></td>
# <td class="Weight">
# 506<small>(+22)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color" id="odds-1_06" style="font-weight : bold">146.9</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_06">9</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019102792&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019102792" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019102792" height="20" id="myhorse1_2019102792" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019102792&amp;race_id=202405030101" id="Bamei_2019102792" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_5" role="row">
# <td class="Waku7 Txt_C"><span>7</span></td>
# <td class="Umaban7 Txt_C">7</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_5" id="mark_5" name="5" style="display: none;">
# <option data-html-text="--" value="7_0">--</option><option data-html-text="◎" value="7_1">◎</option><option data-html-text="◯" value="7_2">◯</option><option data-html-text="▲" value="7_3">▲</option><option data-html-text="△" value="7_4">△</option><option data-html-text="☆" value="7_5">☆</option><option data-html-text="&amp;#10003" value="7_98">&amp;#10003</option><option data-html-text="消" value="7_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019100510" target="_blank" title="キタノブレイド">キタノブレイド<img alt="" class="disp_none Favorite" id="myhorse_2019100510" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01059/" target="_blank" title="石神深">石神深</a>
# </td>
# <td class="Trainer"><span class="Label1">美浦</span><a href="https://db.netkeiba.com/trainer/result/recent/01024/" target="_blank" title="萱野">萱野</a></td>
# <td class="Weight">
# 476<small>(+4)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color Odds_Ninki" id="odds-1_07" style="font-weight : bold">6.4</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_07">4</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019100510&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019100510" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019100510" height="20" id="myhorse1_2019100510" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019100510&amp;race_id=202405030101" id="Bamei_2019100510" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_9" role="row">
# <td class="Waku7 Txt_C"><span>7</span></td>
# <td class="Umaban7 Txt_C">8</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_9" id="mark_9" name="9" style="display: none;">
# <option data-html-text="--" value="8_0">--</option><option data-html-text="◎" value="8_1">◎</option><option data-html-text="◯" value="8_2">◯</option><option data-html-text="▲" value="8_3">▲</option><option data-html-text="△" value="8_4">△</option><option data-html-text="☆" value="8_5">☆</option><option data-html-text="&amp;#10003" value="8_98">&amp;#10003</option><option data-html-text="消" value="8_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019105759" target="_blank" title="フジフォンテ">フジフォンテ<img alt="" class="disp_none Favorite" id="myhorse_2019105759" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01120/" target="_blank" title="大江圭">大江圭</a>
# </td>
# <td class="Trainer"><span class="Label1">美浦</span><a href="https://db.netkeiba.com/trainer/result/recent/01096/" target="_blank" title="粕谷">粕谷</a></td>
# <td class="Weight">
# 464<small>(-4)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color" id="odds-1_08" style="font-weight : bold">163.3</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_08">10</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019105759&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019105759" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019105759" height="20" id="myhorse1_2019105759" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019105759&amp;race_id=202405030101" id="Bamei_2019105759" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_8" role="row">
# <td class="Waku8 Txt_C"><span>8</span></td>
# <td class="Umaban8 Txt_C">9</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_8" id="mark_8" name="8" style="display: none;">
# <option data-html-text="--" value="9_0">--</option><option data-html-text="◎" value="9_1">◎</option><option data-html-text="◯" value="9_2">◯</option><option data-html-text="▲" value="9_3">▲</option><option data-html-text="△" value="9_4">△</option><option data-html-text="☆" value="9_5">☆</option><option data-html-text="&amp;#10003" value="9_98">&amp;#10003</option><option data-html-text="消" value="9_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="HorseName"><a href="https://db.netkeiba.com/horse/2019103005" target="_blank" title="ダノンジャッカル">ダノンジャッカル<img alt="" class="disp_none Favorite" id="myhorse_2019103005" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01005/" target="_blank" title="西谷誠">西谷誠</a>
# </td>
# <td class="Trainer"><span class="Label2">栗東</span><a href="https://db.netkeiba.com/trainer/result/recent/01137/" target="_blank" title="中内田">中内田</a></td>
# <td class="Weight">
# 462<small>(+12)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color Odds_Ninki" id="odds-1_09" style="font-weight : bold">7.5</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_09">5</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019103005&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019103005" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019103005" height="20" id="myhorse1_2019103005" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019103005&amp;race_id=202405030101" id="Bamei_2019103005" title=""></a></div></td>
# </tr>
# <tr class="HorseList" id="tr_3" role="row">
# <td class="Waku8 Txt_C"><span>8</span></td>
# <td class="Umaban8 Txt_C">10</td>
# <td class="CheckMark Horse_Select">
# <select class="makeMeFancy_3" id="mark_3" name="3" style="display: none;">
# <option data-html-text="--" value="10_0">--</option><option data-html-text="◎" value="10_1">◎</option><option data-html-text="◯" value="10_2">◯</option><option data-html-text="▲" value="10_3">▲</option><option data-html-text="△" value="10_4">△</option><option data-html-text="☆" value="10_5">☆</option><option data-html-text="&amp;#10003" value="10_98">&amp;#10003</option><option data-html-text="消" value="10_99">消</option>
# </select><div class="tzSelect" style="width: 40px;"><div class="selectBox">--</div><ul class="dropDown" style="display: none;"><li><span>--</span></li><li><span>◎</span></li><li><span>◯</span></li><li><span>▲</span></li><li><span>△</span></li><li><span>☆</span></li><li><span>✓</span></li><li><span>消</span></li></ul></div>
# </td>
# <td class="HorseInfo">
# <div>
# <div>
# <span class="Icon_HorseMark Icon_MaruChi"></span><span class="HorseName"><a href="https://db.netkeiba.com/horse/2019105578" target="_blank" title="ヴラディア">ヴラディア<img alt="" class="disp_none Favorite" id="myhorse_2019105578" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a></span>
# </div>
# </div>
# </td>
# <td class="Barei Txt_C">牡5</td>
# <td class="Txt_C">60.0</td>
# <td class="Jockey">
# <a href="https://db.netkeiba.com/jockey/result/recent/01087/" target="_blank" title="上野">上野</a>
# </td>
# <td class="Trainer"><span class="Label1">美浦</span><a href="https://db.netkeiba.com/trainer/result/recent/00405/" target="_blank" title="小西">小西</a></td>
# <td class="Weight">
# 496<small>(+2)</small>
# </td>
# <td class="Txt_R Popular"><span class="transition-color" id="odds-1_10" style="font-weight : bold">19.9</span></td>
# <td class="Popular Popular_Ninki Txt_C">
# <span id="ninki-1_10">7</span>
# </td>
# <td class="FavRegist Txt_C">
# <a class="popup_link_04 cboxElement cboxElement_Nologin" href="../popup/horse_bookmark.html?ketto_num=2019105578&amp;race_id=202405030101" title="お気に入り馬登録">
# <img class="horsebookmark myhorse1_2019105578" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001'" src="https://cdn.netkeiba.com/img.race/common/img/icon/prof_icon_favhorse_comp_01.png?2019073001"/>
# <img class="disp_none horsebookmark myhorse_2019105578" height="20" id="myhorse1_2019105578" onmouseout="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" onmouseover="this.src='https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png'" src="https://cdn.netkeiba.com/img.race/common/img/icon/horse_favorite_icon_pc.png" width="20"/>
# </a> </td>
# <td class="FavMemo"><div><a class="popup_link_04 cboxElement" href="../popup/horse_bookmark.html?ketto_num=2019105578&amp;race_id=202405030101" id="Bamei_2019105578" title=""></a></div></td>
# </tr>
# </tbody>
# </table>

# %%
import re

soup.find_all("a", href=re.compile(r"/horse/"))
# Out:
# [<a href="https://db.netkeiba.com/horse/2019100108" target="_blank" title="プリモスペランツァ">プリモスペランツァ<img alt="" class="disp_none Favorite" id="myhorse_2019100108" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019104899" target="_blank" title="インプレス">インプレス<img alt="" class="disp_none Favorite" id="myhorse_2019104899" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2016103092" target="_blank" title="コルドゥーン">コルドゥーン<img alt="" class="disp_none Favorite" id="myhorse_2016103092" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2020102800" target="_blank" title="オメガリッチマン">オメガリッチマン<img alt="" class="disp_none Favorite" id="myhorse_2020102800" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019105143" target="_blank" title="インディゴブラック">インディゴブラック<img alt="" class="disp_none Favorite" id="myhorse_2019105143" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019102792" target="_blank" title="スペキュレーター">スペキュレーター<img alt="" class="disp_none Favorite" id="myhorse_2019102792" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019100510" target="_blank" title="キタノブレイド">キタノブレイド<img alt="" class="disp_none Favorite" id="myhorse_2019100510" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019105759" target="_blank" title="フジフォンテ">フジフォンテ<img alt="" class="disp_none Favorite" id="myhorse_2019105759" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019103005" target="_blank" title="ダノンジャッカル">ダノンジャッカル<img alt="" class="disp_none Favorite" id="myhorse_2019103005" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>,
#  <a href="https://db.netkeiba.com/horse/2019105578" target="_blank" title="ヴラディア">ヴラディア<img alt="" class="disp_none Favorite" id="myhorse_2019105578" src="https://cdn.netkeiba.com/img.race/common/img/icon/icon_horse.png?2019073001" width="18"/></a>]

# %%
# %autoreload

# %%
pfc = PredictionFeatureCreator()
pfc.fetch_shutuba_table_html(race_id="202405030101")

# %%
pfc.htmls["202405030101"]
# Out:
# '<html><head><script async="" src="https://www.clarity.ms/s/0.7.34/clarity.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/article-detection.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/distance-from-article.20240530-42-RELEASE.es6.js"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/userx.20240530-42-RELEASE.es6.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-BQDXGQBP6X&amp;l=dataLayer&amp;cx=c"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-B2L5N4JT6V&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.clarity.ms/tag/dfos4lrrd0"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><style type="text/css">.swal-icon--error{border-color:#f27474;-webkit-animation:animateErrorIcon .5s;animation:animateErrorIcon .5s}.swal-icon--error__x-mark{position:relative;display:block;-webkit-animation:animateXMark .5s;animation:animateXMark .5s}.swal-icon--error__line{position:absolute;height:5px;width:47px;background-color:#f27474;display:block;top:37px;border-radius:2px}.swal-icon--error__line--left{-webkit-transform:rotate(45deg);transform:rotate(45deg);left:17px}.swal-icon--error__line--right{-webkit-transform:rotate(-45deg);transform:rotate(-45deg);right:16px}@-webkit-keyframes animateErrorIcon{0%{-webkit-transform:rotateX(100deg);transform:rotateX(100deg);opacity:0}to{-webkit-transform:rotateX(0deg);transform:rotateX(0deg);opacity:1}}@keyframes animateErrorIcon{0%{-webkit-transform:rotateX(100deg);transform:rotateX(100deg);opacity:0}to{-webkit-transform:rotateX(0deg);transform:rotateX(0deg);opacity:1}}@-webkit-keyframes animateXMark{0%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}50%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}80%{-webkit-transform:scale(1.15);transform:scale(1.15);margin-top:-6px}to{-webkit-transform:scale(1);transform:scale(1);margin-top:0;opacity:1}}@keyframes animateXMark{0%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}50%{-webkit-transform:scale(.4);transform:scale(.4);margin-top:26px;opacity:0}80%{-webkit-transform:scale(1.15);transform:scale(1.15);margin-top:-6px}to{-webkit-transform:scale(1);transform:scale(1);margin-top:0;opacity:1}}.swal-icon--warning{border-color:#f8bb86;-webkit-animation:pulseWarning .75s infinite alternate;animation:pulseWarning .75s infinite alternate}.swal-icon--warning__body{width:5px;height:47px;top:10px;border-radius:2px;margin-left:-2px}.swal-icon--warning__body,.swal-icon--warning__dot{position:absolute;left:50%;background-color:#f8bb86}.swal-icon--warning__dot{width:7px;height:7px;border-radius:50%;margin-left:-4px;bottom:-11px}@-webkit-keyframes pulseWarning{0%{border-color:#f8d486}to{border-color:#f8bb86}}@keyframes pulseWarning{0%{border-color:#f8d486}to{border-color:#f8bb86}}.swal-icon--success{border-color:#a5dc86}.swal-icon--success:after,.swal-icon--success:before{content:"";border-radius:50%;position:absolute;width:60px;height:120px;background:#fff;-webkit-transform:rotate(45deg);transform:rotate(45deg)}.swal-icon--success:before{border-radius:120px 0 0 120px;top:-7px;left:-33px;-webkit-transform:rotate(-45deg);transform:rotate(-45deg);-webkit-transform-origin:60px 60px;transform-origin:60px 60px}.swal-icon--success:after{border-radius:0 120px 120px 0;top:-11px;left:30px;-webkit-transform:rotate(-45deg);transform:rotate(-45deg);-webkit-transform-origin:0 60px;transform-origin:0 60px;-webkit-animation:rotatePlaceholder 4.25s ease-in;animation:rotatePlaceholder 4.25s ease-in}.swal-icon--success__ring{width:80px;height:80px;border:4px solid hsla(98,55%,69%,.2);border-radius:50%;box-sizing:content-box;positi ...

# %%
pfc.create_features(race_id="202405030101")

# %%
pfc = PredictionFeatureCreator()
pfc.fetch_results(race_id="202405030101", html=html)
# Out:
# /Users/chiyoda/repositories/keibaAI-v3-yt/v3_0_0/src/feature_engineering.py:161: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.

# %%
pfc.results
# Out:
#         race_id    horse_id jockey_id trainer_id  umaban  wakuban  \
# 0  202405030101  2019100108     01105      01039       1        1
# 1  202405030101  2019104899     01196      00429       2        2
# 2  202405030101  2016103092     01149      01043       3        3
# 3  202405030101  2020102800     01046      01164       4        4
# 4  202405030101  2019105143     01063      01146       5        5
# 5  202405030101  2019102792     01023      01031       6        6
# 6  202405030101  2019100510     01059      01024       7        7
# 7  202405030101  2019105759     01120      01096       8        7
# 8  202405030101  2019103005     01005      01137       9        8
# 9  202405030101  2019105578     01087      00405      10        8
#
#    tansho_odds  popularity  impost  sex  age  weight  weight_diff
# 0          3.1           1    60.0    0    5     500           -6
# 1          5.1           3    60.0    0    5     526          -12
# 2        121.9           8    60.0    0    8     474           12
# 3          3.5           2    60.0    0    4     446           -2
# 4         10.0           6    60.0    2    5     512            2
# 5        146.9           9    60.0    0    5     506           22
# 6          6.4           4    60.0    0    5     476            4
# 7        163.3          10    60.0    0    5     464           -4
# 8          7.5           5    60.0    0    5     462           12
# 9         19.9           7    60.0    0    5     496            2

# %% [markdown]
# ### レース情報テーブルの取得

# %% [markdown]
# race_id	date	race_type	around	course_len	weather	ground_state	race_class	place

# %%
soup = BeautifulSoup(html, "lxml").find("div", class_="RaceList_Item02")
soup
# Out:
# <div class="RaceList_Item02">
# <h1 class="RaceName">3歳以上障害未勝利
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# </h1>
# <div class="RaceData01">
# 10:05発走 /<!-- <span class="Turf"> --><span> 障3000m</span> (芝 ダート)
# / 天候:晴<span class="Icon_Weather Weather01"></span>
# <span class="Item03">/ 馬場:稍</span>
# <span class="Item04">/ 馬場:重</span>
# </div>
# <div class="RaceData02">
# <span>3回</span>
# <span>東京</span>
# <span>1日目</span>
# <span>障害３歳以上</span>
# <span>未勝利</span>
#
# <span>(混)</span>
# <span>定量</span>
# <span>10頭</span>
# <br/>
# <span>本賞金:790,320,200,120,79万円</span>
# </div>
# </div>

# %%
# タイトル
soup.find("h1").text.strip()
# Out:
# '3歳以上障害未勝利'

# %%
div0 = soup.find_all("div")[0]
div0.text
# Out:
# '\n10:05発走 / 障3000m (芝 ダート)\n/ 天候:晴\n/ 馬場:稍\n/ 馬場:重\n'

# %%
info1 = re.findall(r"[\w:]+", div0.text)
info1
# Out:
# ['10:05発走', '障3000m', '芝', 'ダート', '天候:晴', '馬場:稍', '馬場:重']

# %%
info1[1][0]
# Out:
# '障'

# %%
int(re.findall(r"\d+", info1[1])[0])
# Out:
# 3000

# %%
re.findall(r"天候:(\w+)", div0.text)
# Out:
# ['晴']

# %%
re.findall(r"馬場:(\w+)", div0.text)[0]
# Out:
# '稍'

# %%
soup.find_all("div")[1].text
# Out:
# '\n3回\n東京\n1日目\n障害３歳以上\n未勝利\n\xa0\xa0\xa0\xa0\xa0\n(混)\n定量\n10頭\n\n本賞金:790,320,200,120,79万円\n'

# %%
import json
from pathlib import Path


# commonディレクトリのパス
COMMON_DATA_DIR = Path("..", "..", "common", "data")
POPULATION_DIR = COMMON_DATA_DIR / "prediction_population"
MAPPING_DIR = COMMON_DATA_DIR / "mapping"
# v3_0_0ディレクトリのパス
DATA_DIR = Path("..", "data")
INPUT_DIR = DATA_DIR / "01_preprocessed"
OUTPUT_DIR = DATA_DIR / "02_features"
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# カテゴリ変数を数値に変換するためのマッピング
with open(MAPPING_DIR / "race_class.json", "r") as f:
    race_class_mapping = json.load(f)

# %%
regex_race_class = "|".join(race_class_mapping)

# %%
race_class_mapping
# Out:
# {'新馬': 0,
#  '未勝利': 1,
#  '1勝クラス': 2,
#  '2勝クラス': 3,
#  '3勝クラス': 4,
#  'オープン': 5,
#  'G3': 6,
#  'G2': 7,
#  'G1': 8,
#  '特別': 5,
#  '500万下': 2,
#  '1000万下': 3,
#  '1600万下': 4,
#  'OP': 5}

# %%
re.findall(rf"{regex_race_class}", soup.find_all("div")[1].text)
# Out:
# ['未勝利']

# %%
# %autoreload

# %%
pfc = PredictionFeatureCreator()
pfc.fetch_race_info(race_id="202405030101", html=html)

# %%
pfc.race_info
# Out:
#         race_id  race_type around  course_len  weather  ground_state  \
# 0  202405030101          2   None        3000        1             2
#
#    race_class  place
# 0           1      5

# %%
pfc.population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      328 non-null    object
#  1   race_id   328 non-null    int64
#  2   horse_id  328 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 7.8+ KB

# %%
pfc = PredictionFeatureCreator()
features = pfc.create_features(race_id="202405030101")
# Out:
# /Users/chiyoda/repositories/keibaAI-v3-yt/v3_0_0/src/feature_engineering.py:166: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df.columns = df.columns.get_level_values(1)

# %% [markdown]
# ## 予測

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             10 non-null     object
#  1   race_id          10 non-null     int64
#  2   horse_id         10 non-null     int64
#  3   jockey_id        10 non-null     int64
#  4   trainer_id       10 non-null     int64
#  5   umaban           10 non-null     int64
#  6   wakuban          10 non-null     int64
#  7   tansho_odds      10 non-null     float64
#  8   popularity       10 non-null     int64
#  9   impost           10 non-null     float64
#  10  sex              10 non-null     int64
#  11  age              10 non-null     int64
#  12  weight           10 non-null     int64
#  13  weight_diff      10 non-null     int64
#  14  race_type        10 non-null     int64
#  15  around           0 non-null      float64
#  16  course_len       10 non-null     int64
#  17  weather          10 non-null     int64
#  18  ground_state     10 non-null     int64
#  19  race_class       10 non-null     int64
#  20  place            10 non-null     int64
#  21  rank_3races      10 non-null     float64
#  22  prize_3races     10 non-null     float64
#  23  rank_5races      10 non-null     float64
#  24  prize_5races     10 non-null     float64
#  25  rank_10races     10 non-null     float64
#  26  prize_10races    10 non-null     float64
#  27  rank_1000races   10 non-null     float64
#  28  prize_1000races  10 non-null     float64
# dtypes: float64(11), int64(17), object(1)
# memory usage: 2.4+ KB

# %%
import prediction

prediction.predict(features, config_filepath="config.yaml")
# Out:
#         race_id  umaban  tansho_odds  popularity      pred
# 3  202405030101       4          3.5           2  0.325319
# 0  202405030101       1          3.1           1  0.239033
# 8  202405030101       9          7.5           5  0.138848
# 1  202405030101       2          5.1           3  0.131458
# 6  202405030101       7          6.4           4  0.086023
# 4  202405030101       5         10.0           6  0.084488
# 9  202405030101      10         19.9           7  0.054749
# 5  202405030101       6        146.9           9  0.001212
# 2  202405030101       3        121.9           8  0.000887
# 7  202405030101       8        163.3          10  0.000821
